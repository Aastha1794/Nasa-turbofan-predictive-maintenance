# %% [markdown]
# <a href="https://colab.research.google.com/github/Aastha1794/Nasa-turbofan-predictive-maintenance/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("🚀 NASA Turbofan Predictive Maintenance Project")
# Out:
# 🚀 NASA Turbofan Predictive Maintenance Project

# %%
print("=" * 50)

# %%
# Test basic functionality
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Create sample data
data = np.random.randn(100, 5)
df = pd.DataFrame(data, columns=[f'sensor_{i}' for i in range(1, 6)])

print("Sample sensor data created:")
print(df.head())
# Out:
# Sample sensor data created:
#    sensor_1  sensor_2  sensor_3  sensor_4  sensor_5
# 0  0.199600 -1.009081  0.330941 -1.139644  1.299785
# 1 -0.721173  2.097994  0.932448  0.284866  1.172609
# 2  0.221692  0.002549 -0.530649 -0.926645 -0.143091
# 3 -1.984936  1.008211  0.742969  0.020975  0.563671
# 4 -0.309722  0.015273  0.913707 -1.124947  1.981832

# %%
# Simple visualization
plt.figure(figsize=(10, 6))
plt.plot(df['sensor_1'], label='Sensor 1')
plt.plot(df['sensor_2'], label='Sensor 2')
plt.legend()
plt.title('Sample Sensor Data')
plt.show()

print("✅ Setup complete! Ready to start the project.")
# Out:
# ✅ Setup complete! Ready to start the project.
